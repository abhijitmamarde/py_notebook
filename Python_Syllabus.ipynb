# %% [markdown]
# # Python Syllabus:
#
#
# ## Part - 1
#
# - What is Python and history of Python?
#
# - Unique features of Python
#
# - Python-2 and Python-3 differences
#
# - Install Python and Environment  Setup
#
# - First Python Program
#
# - Python Identifiers, Keywords and Indentation
#
# - Comments and document interlude in Python
#
# - Command line arguments
#
# - Getting User Input
#
# - Python Data Types
#
# - What are variables?
#
# - Python Core objects and Functions
#
# - Built in modules (Library Functions)
#
# - Number and Maths
#
#
#
# ## Part - 2
#
# - String, List, Tuples and Dictionaries
#
# - Manipulations of String, List, Tuple and Dictionaries
#
# - Taking a `slice` in Python
#
# - Python built in functions
#
# - Python user defined functions
#
# - Python packages functions
#
# - Defining and calling Function
#
# - The anonymous Functions – `Lambda` Functions
#
# - Loops and statement in Python
#
# - Python Modules & Packages
#
# - Python File Handling
#
# - Pythons and Directories manipulations
#
#
#
# ## Part - 3
#
# - Python Object Oriented
#
#    - Overview of OOP
#
#    - Creating Classes and Objects
#
#    - Accessing attributes
#
#    - Built-In Class Attributes
#
#    - Destroying Objects
#
#    - Class Inheritance
#
#    - Overriding Methods
#
#    - Overloading Operators
#
#    - Data Hiding
#
# - Python and Exceptions
#
#    - What is Exception?
#
#    - Handling an exception
#
#    - `try`, `except` clause
#
#    - `else` clause
#
#    - `finally` clause
#
#    - Argument of an Exception
#
#    - Python Standard Exceptions
#
#    - Raising an exceptions using `raise`
#
#    - User-Defined Exceptions
#
#
#
#
#
# ## Part-4
#
# - Python Regular Expressions
#
#    - What are regular expressions?
#
#    - Common regular expression patterns
#
#    - The `find_all` Function
#
#    - The `search` Function
#
#    - The `match` Function
#
#    - Matching vs searching
#
#    - Search and Replace using `sub` function
#
# - Python Multithreaded Programming
#
#    - What is multithreading?
#
#    - Starting a New Thread
#
#    - The Threading Module
#
#    - Synchronizing Threads
#
#    - Multithreaded Priority Queue
#
#
#
#
# ## PART-5
#
# - Python database programming using Pony ORM
#
#    - Installing `ponyorm`
#
#    - Creating database connection
#
#    - DDL, and DML Operations
#
#    - CREATE, INSERT, READ, UPDATE and DELETE Operation
#
#    - Performing Transactions - Commits and Rollbacks
#
#    - Handling common Errors
#
#    - Closing database connection
#
# - Web Scraping in Python using package BeautifulSoup
#
#    - Installing required packages: `bs4` and `requests`
#
#    - HTML Basics - Tags and DOM
#
#    - Sample programs
